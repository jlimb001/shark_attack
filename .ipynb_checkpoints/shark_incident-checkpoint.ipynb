# %%
# pip install xlrd

# %%
import pandas as pd
import numpy as np
import xlrd

df = pd.read_excel("C:/Users/jugal/OneDrive/Documents/Ironhack/shark_business/shark_detail.xls")

# %%
df.head()
# Out:
#                   Date    Year        Type    Country       State  \
# 0                  NaN     NaN         NaN        NaN         NaN
# 1  2024-11-01 00:00:00  2024.0  Unprovoked     Hawaii        Maui
# 2  2024-10-31 00:00:00  2024.0  Unprovoked  Australia  Queensland
# 3  2024-10-25 00:00:00  2024.0  Unprovoked        USA     Florida
# 4  2024-10-14 00:00:00  2024.0  Unprovoked   Honduras        Tela
#
#                        Location    Activity                      Name  Sex  \
# 0                           NaN         NaN                       NaN  NaN
# 1  Sand Piles Waiehu Beach Park     Surfing                     Kenji    M
# 2            Whitsunday Islands  Snorkeling                Not stated    F
# 3  Bathtub Beach, Martin County     Surfing             Cole Taschman    M
# 4                     Atlantida    Swimming  Roberto Carlose Bu Mejia    M
#
#    Age  ...                         Species   \
# 0  NaN  ...                              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6977 entries, 0 to 6976
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6976 non-null   object
#  1   Year            6974 non-null   float64
#  2   Type            6958 non-null   object
#  3   Country         6926 non-null   object
#  4   State           6494 non-null   object
#  5   Location        6411 non-null   object
#  6   Activity        6390 non-null   object
#  7   Name            6756 non-null   object
#  8   Sex             6397 non-null   object
#  9   Age             3981 non-null   object
#  10  Injury          6941 non-null   object
#  11  Unnamed: 11     6414 non-null   object
#  12  Time            3450 non-null   object
#  13  Species         3844 non-null   object
#  14  Source          6957 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
# ...

# %%
df.tail()
# Out:
#              Date  Year        Type             Country              State  \
# 6972  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6973  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 6974    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 6975    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 6976    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 6972                          Roebuck Bay        Diving
# 6973                                  NaN  Pearl diving
# 6974                       Ocracoke Inlet      Swimming
# 6975                 Panama Bay 8ºN, 79ºW           NaN
# 6976  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  ... Species   \
# 6972                   male   M  NaN  ...      NaN
# 6973                  Ahmun   M  NaN  ...      NaN
# ...

# %%
df.isnull()
# Out:
#        Date   Year   Type  Country  State  Location  Activity   Name    Sex  \
# 0      True   True   True     True   True      True      True   True   True
# 1     False  False  False    False  False     False     False  False  False
# 2     False  False  False    False  False     False     False  False  False
# 3     False  False  False    False  False     False     False  False  False
# 4     False  False  False    False  False     False     False  False  False
# ...     ...    ...    ...      ...    ...       ...       ...    ...    ...
# 6972  False  False  False    False  False     False     False  False  False
# 6973  False  False  False    False  False      True     False  False  False
# 6974  False  False  False    False  False     False     False  False  False
# 6975  False  False  False    False   True     False      True  False  False
# 6976  False  False  False    False  False     False     False  False  False
#
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"], errors="coerce")
df.head(10)
# Out:
#         Date    Year        Type    Country             State  \
# 0        NaT     NaN         NaN        NaN               NaN
# 1 2024-11-01  2024.0  Unprovoked     Hawaii              Maui
# 2 2024-10-31  2024.0  Unprovoked  Australia        Queensland
# 3 2024-10-25  2024.0  Unprovoked        USA           Florida
# 4 2024-10-14  2024.0  Unprovoked   Honduras              Tela
# 5 2024-10-11  2024.0  Unprovoked        USA           Florida
# 6 2024-09-17  2024.0  Unprovoked   Honduras    Trujillo Colon
# 7 2024-09-16  2024.0  Unprovoked    Morocco  Southern Morocco
# 8 2024-08-26  2024.0  Unprovoked    Jamaica       Montego Bay
# 9 2024-08-06  2024.0  Unprovoked     Belize  Gulf of Honduras
#
#                        Location                     Activity  \
# 0                           NaN                          NaN
# 1  Sand Piles Waiehu Beach Park                      Surfing
# 2            Whitsunday Islands                   Snorkeling
# ...

# %%
df["Year"]=pd.to_datetime(df["Year"], errors="coerce")
df.head()
# Out:
#         Date                          Year        Type    Country       State  \
# 0        NaT                           NaT         NaN        NaN         NaN
# 1 2024-11-01 1970-01-01 00:00:00.000002024  Unprovoked     Hawaii        Maui
# 2 2024-10-31 1970-01-01 00:00:00.000002024  Unprovoked  Australia  Queensland
# 3 2024-10-25 1970-01-01 00:00:00.000002024  Unprovoked        USA     Florida
# 4 2024-10-14 1970-01-01 00:00:00.000002024  Unprovoked   Honduras        Tela
#
#                        Location    Activity                      Name  Sex  \
# 0                           NaN         NaN                       NaN  NaN
# 1  Sand Piles Waiehu Beach Park     Surfing                     Kenji    M
# 2            Whitsunday Islands  Snorkeling                Not stated    F
# 3  Bathtub Beach, Martin County     Surfing             Cole Taschman    M
# 4                     Atlantida    Swimming  Roberto Carlose Bu Mejia    M
#
# ...

# %%
#df["Type"]=pd.to_datetime(df["Type"])

# %%
df.drop(['href', 'pdf', 'href formula','original order', 'Unnamed: 21', 'Unnamed: 22'],  axis=1)
# Out:
#            Date                          Year        Type             Country  \
# 0           NaT                           NaT         NaN                 NaN
# 1    2024-11-01 1970-01-01 00:00:00.000002024  Unprovoked              Hawaii
# 2    2024-10-31 1970-01-01 00:00:00.000002024  Unprovoked           Australia
# 3    2024-10-25 1970-01-01 00:00:00.000002024  Unprovoked                 USA
# 4    2024-10-14 1970-01-01 00:00:00.000002024  Unprovoked            Honduras
# ...         ...                           ...         ...                 ...
# 6972        NaT 1970-01-01 00:00:00.000000000  Unprovoked           AUSTRALIA
# 6973        NaT 1970-01-01 00:00:00.000000000  Unprovoked           AUSTRALIA
# 6974        NaT 1970-01-01 00:00:00.000000000  Unprovoked                 USA
# 6975        NaT 1970-01-01 00:00:00.000000000  Unprovoked              PANAMA
# 6976        NaT 1970-01-01 00:00:00.000000000  Unprovoked  CEYLON (SRI LANKA)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6977 entries, 0 to 6976
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6101 non-null   datetime64[ns]
#  1   Year            6974 non-null   datetime64[ns]
#  2   Type            6958 non-null   object
#  3   Country         6926 non-null   object
#  4   State           6494 non-null   object
#  5   Location        6411 non-null   object
#  6   Activity        6390 non-null   object
#  7   Name            6756 non-null   object
#  8   Sex             6397 non-null   object
#  9   Age             3981 non-null   object
#  10  Injury          6941 non-null   object
#  11  Unnamed: 11     6414 non-null   object
#  12  Time            3450 non-null   object
#  13  Species         3844 non-null   object
#  14  Source          6957 non-null   object
#  15  pdf             6799 non-null   object
# ...

# %%
df['Time'] = df['Time'].astype('int64').astype('int32').round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6977 entries, 0 to 6976
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6101 non-null   datetime64[ns]
#  1   Year            6974 non-null   datetime64[ns]
#  2   Type            6958 non-null   object
#  3   Country         6926 non-null   object
#  4   State           6494 non-null   object
#  5   Location        6411 non-null   object
#  6   Activity        6390 non-null   object
#  7   Name            6756 non-null   object
#  8   Sex             6397 non-null   object
#  9   Age             3981 non-null   object
#  10  Injury          6941 non-null   object
#  11  Unnamed: 11     6414 non-null   object
#  12  Time            6977 non-null   int32
#  13  Species         3844 non-null   object
#  14  Source          6957 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
# ...

# %%
df.head()
# Out:
#         Date                          Year        Type    Country       State  \
# 0        NaT                           NaT         NaN        NaN         NaN
# 1 2024-11-01 1970-01-01 00:00:00.000002024  Unprovoked     Hawaii        Maui
# 2 2024-10-31 1970-01-01 00:00:00.000002024  Unprovoked  Australia  Queensland
# 3 2024-10-25 1970-01-01 00:00:00.000002024  Unprovoked        USA     Florida
# 4 2024-10-14 1970-01-01 00:00:00.000002024  Unprovoked   Honduras        Tela
#
#                        Location    Activity                      Name  Sex  \
# 0                           NaN         NaN                       NaN  NaN
# 1  Sand Piles Waiehu Beach Park     Surfing                     Kenji    M
# 2            Whitsunday Islands  Snorkeling                Not stated    F
# 3  Bathtub Beach, Martin County     Surfing             Cole Taschman    M
# 4                     Atlantida    Swimming  Roberto Carlose Bu Mejia    M
#
# ...

# %%
df['Time']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6972    0
# 6973    0
# 6974    0
# 6975    0
# 6976    0
# Name: Time, Length: 6977, dtype: int32
